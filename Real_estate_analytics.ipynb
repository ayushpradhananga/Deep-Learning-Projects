# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushpradhananga/Deep-Learning-Projects/blob/main/Real_estate_analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Real estate analytics with tabular data

# %% [markdown]
# ## Table of Content
#
# 1. [Executive Summary](#cell_Summary)
#
# 2. [Data Preprocessing](#cell_Preprocessing)
#
# 3. [Predictive Modeling](#cell_model)
#
# 4. [Experiments Report](#cell_report)

# %% [markdown]
# <a id = "cell_Summary"></a>
# ## 1. Executive Summary

# %% [markdown]
# *Use this section to introduce the business problem, data set, method, experiments, and obtained results*

# %% [markdown]
# **Problem Definition:**
#
# The objective of this project is to analyze a dataset of house sales in King County, USA, containing over 21,613 records, and develop AI solutions to address the business needs of a real estate company.
#
# **My primary tasks are:**
#
# 1. Evaluate the performance of regression models (linear regression and neural networks) to predict house prices.
# 2. Convert house prices into a nominal attribute, "High_Price" for prices 450,000 or more, and "Low_Price" for prices less than 450,000. Evaluate the performance of classification models (neural networks and another model) for this classification task.
#
# **Business Benefit:**
#
# The successful completion of this project will provide valuable insights and predictive capabilities to the real estate company. By accurately estimating house prices and categorizing them into high and low price segments, I can assist the company in making informed decisions regarding property valuation and investment.
#
# **Proposed Approaches:**
#
# For the regression task, I employed two models:
#
# **Linear Regression:** A traditional model widely used for predicting numeric values based on input features.
#
# **Neural Networks:** Utilizing deep learning techniques, specifically Multilayer Perceptron (MLP), to capture complex relationships within the data.
#
# For the classification task, I used:
#
# **Neural Networks:** Deep learning model known for its ability to handle complex patterns and relationships.
#
# **Gradient Boosting:** Classification model chosen to compare performance with neural networks.
#
# In addition I did some experient with other classification model.
#
# **Major Findings:**
#
# **Regression Model Performance Evaluation:**
#
# **Linear Regression:** The linear regression model provided reasonable predictive performance with a correlation score of 0.831 between true and predicted values.
#
# **Neural Networks:** The neural network model outperformed linear regression significantly in terms of estimation with correlation score of 0.89 between true and predicted values. It's performance was also significantly better for bith training and testing dataset. It demonstrated the ability to capture nonlinear relationships in the data, leading to superior estimation performance. The neural network model is recommended for accurate house price estimation.
#
# **Classification Model Performance Evaluation:**
#
# **Neural Networks:** The neural network model exhibited strong classification performance, accurately categorizing houses into high and low price segments. It had higher accuracy for classifying high price houses than gradient boosting. Also, the kappa and accuracy was slightly better.
#
# **Gradient Boosting:**  The Gradient Boosting classification model also showed strong performance identical to neural network in terms of metrics. It had better classification for Low price houses than neural network.
#
# In conclusion, neural networks proved to be highly beneficial in addressing the real estate company's business needs. The neural network models excelled in both house price estimation and price classification tasks, offering the company valuable tools for decision-making and market analysis

# %% [markdown]
# <a id = "cell_Preprocessing"></a>
# ## 2. Data Preprocessing

# %% [markdown]
# *Carry out necessary data preprocessing and exploration.*

# %% [markdown]
# ###Import Libraries and data

# %%
from __future__ import print_function
import os
import math
import datetime
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.metrics import mean_absolute_error
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#Import file
house_price_data = pd.read_csv("Part1_house_price.csv")
#View head of the data
house_price_data.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  condition  grade  \
# 21608         1530      1131     3.0           0     0          3      8
# 21609         2310      5813     2.0           0     0          3      8
# 21610         1020      1350     2.0           0     0          3      7
# 21611         1600      2388     2.0           0     0          3      8
# 21612         1020      1076     2.0           0     0          3      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357

# %% [markdown]
# ###Data Exploration

# %%
#Viewing data types
house_price_data.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
# Identification of missing values
missing_data = house_price_data.isnull().sum()
missing_data = missing_data[missing_data > 0]
missing_data.sort_values(ascending=False)
# Out:
# Series([], dtype: int64)

# %% [markdown]
# There are no missing values in the dataset.

# %%
# Compute correlation matrix
corr = house_price_data.corr(method='pearson')

# Plot correlation heatmap
sns.set(rc={'figure.figsize': (15, 10)})
ax = sns.heatmap(corr, annot=True, fmt=".2f", cmap="Blues")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-5-fa9b2cc5e12c>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = house_price_data.corr(method='pearson')

# %%
#Rank correlation coefficient with price
price_corr = house_price_data.corr()['price'].sort_values(ascending=False)
print(price_corr)
# Out:
# price            1.000000
# sqft_living      0.702044
# grade            0.667463
# sqft_above       0.605566
# sqft_living15    0.585374
# bathrooms        0.525134
# view             0.397346
# sqft_basement    0.323837
# bedrooms         0.308338
# lat              0.306919
# waterfront       0.266331
# floors           0.256786
# yr_renovated     0.126442
# sqft_lot         0.089655
# sqft_lot15       0.082456
# yr_built         0.053982
# condition        0.036392
# long             0.021571
# id              -0.016797
# zipcode         -0.053168
# Name: price, dtype: float64
# <ipython-input-6-0dd502f7f78f>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   price_corr = house_price_data.corr()['price'].sort_values(ascending=False)

# %%
# Convert Date attribute to Datetype
house_price_data['date'] = pd.to_datetime(house_price_data['date'])

# Create new columns month and year based on date
house_price_data['month'] = house_price_data['date'].apply(lambda date:date.month)
house_price_data['year'] = house_price_data['date'].apply(lambda date:date.year)

# Check the new columns
print(house_price_data.columns.values)
# Out:
# ['id' 'date' 'price' 'bedrooms' 'bathrooms' 'sqft_living' 'sqft_lot'
#  'floors' 'waterfront' 'view' 'condition' 'grade' 'sqft_above'
#  'sqft_basement' 'yr_built' 'yr_renovated' 'zipcode' 'lat' 'long'
#  'sqft_living15' 'sqft_lot15' 'month' 'year']

# %%
# Drop columns we don't need
house_price_data = house_price_data.drop(columns=['id','zipcode','date'])

# %% [markdown]
# ###Feature Selection

# %%
# Split the data into X & y
X = house_price_data.drop(['price'], axis = 1)
y = house_price_data['price']

print(X.shape)
print(y.shape)
# Out:
# (21613, 19)
# (21613,)

# %% [markdown]
# ###Data Scaling and Creating Training and Test Sets

# %%
# Import scaler
from sklearn.preprocessing import MinMaxScaler

# Scaling the features using MinMaxScaler
scaler = MinMaxScaler()
X_scale = scaler.fit_transform(X)

# Split the data into training and test sets
from sklearn.model_selection import train_test_split # Import train_test_split function
X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size=0.3, stratify=None, random_state=2023)

# %%
print('Missing training values before imputation = ', np.isnan(X_train).sum())
print('Missing validation values before imputation = ', np.isnan(X_test).sum())
print('X train min =', round(X_train.min().min(),4), '; max =', round(X_train.max().max(), 4))
print('X valid min =', round(X_test.min().min(),4), '; max =', round(X_test.max().max(), 4))
# Out:
# Missing training values before imputation =  0
# Missing validation values before imputation =  0
# X train min = 0.0 ; max = 1.0
# X valid min = 0.0 ; max = 1.0

# %%
# Print the shapes of the training and testing sets
training_shape = X_train.shape
validation_shape = X_test.shape
training_samples = training_shape[0]
validation_samples = validation_shape[0]

print("Training shape: ({}, {})".format(training_shape[0], training_shape[1]))
print("Training samples: ", training_samples)
print("Validation samples: ", validation_samples)
# Out:
# Training shape: (15129, 19)
# Training samples:  15129
# Validation samples:  6484

# %% [markdown]
# <a id = "cell_model"></a>
# ## 3. Predictive Modeling

# %% [markdown]
# *Create and explain your models (e.g., model architecture, model parameters). Evaluate the models on the experimental data sets.*

# %%
import tensorflow as tf
from tensorflow.keras import metrics
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Nadam, RMSprop

# evaluation on test data
from sklearn.metrics import mean_squared_error,mean_absolute_error,explained_variance_score
from sklearn.metrics import classification_report,confusion_matrix

# %% [markdown]
# ###**Price Estimation**

# %% [markdown]
# Here, we compare the performance of two models: linear regression and neural network for house price prediction.

# %% [markdown]
# ####**Linear Regression Model Creation and Training**

# %%
from sklearn.linear_model import LinearRegression

# Create a Linear Regression model
linear_reg_model = LinearRegression()

# Fit the model to your training data
linear_reg_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ####Model Evaluation and Prediction

# %%
# Make predictions on the training data
linear_reg_train_predictions = linear_reg_model.predict(X_train)

# Calculate and print metrics for the training set
train_mae = mean_absolute_error(y_train, linear_reg_train_predictions)
train_mse = mean_squared_error(y_train, linear_reg_train_predictions)
train_rmse = np.sqrt(train_mse)

print('Linear Regresssion Training MAE: ', train_mae)
print('Linear Regresssion Training MSE: ', train_mse)
print('Linear Regresssion Training RMSE: ', train_rmse)

# Make predictions on the test data
linear_reg_test_predictions = linear_reg_model.predict(X_test)

# Calculate and print metrics for the test set
test_mae = mean_absolute_error(y_test, linear_reg_test_predictions)
test_mse = mean_squared_error(y_test, linear_reg_test_predictions)
test_rmse = np.sqrt(test_mse)

print('Linear Regresssion Test MAE: ', test_mae)
print('Linear RegresssionTest MSE: ', test_mse)
print('Linear Regresssion Test RMSE: ', test_rmse)
# Out:
# Linear Regresssion Training MAE:  127491.78826789187
# Linear Regresssion Training MSE:  42133897373.944954
# Linear Regresssion Training RMSE:  205265.43151233468
# Linear Regresssion Test MAE:  125526.68849489385
# Linear RegresssionTest MSE:  38171940875.01098
# Linear Regresssion Test RMSE:  195376.4081843327

# %% [markdown]
# ####Plotting True vs Predicted values

# %%
plt.scatter(y_test, linear_reg_test_predictions)
plt.ylabel('True Values')
plt.xlabel('Predicted values')
plt.show()
# Calculate the correlation coefficient
corr = np.corrcoef(y_test, linear_reg_test_predictions)

# Extract the correlation coefficient from the result
cor_coefficient = corr[0, 1]

# Print the correlation coefficient
print('The Correlation between y_test and y_predict is:', round(cor_coefficient, 3))
# Out:
# The Correlation between y_test and y_predict is: 0.831

# %% [markdown]
# ####**Neural Network**

# %% [markdown]
# An activation function is essential in a neural network because it introduces non-linearity, allowing the network to handle complex patterns and relationships. Without an activation function, the network behaves like a linear regression model, which is limited in its capabilities.
#
# Neural networks are assumed to perform better than linear models because they can capture intricate, non-linear data patterns. The 'relu' activation function, for example, enables neural networks to model a wide range of non-linear functions, making them powerful tools for tasks like regression.

# %%
# Define your neural network model
ann = Sequential([
    Dense(100, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(50, activation='relu'),
    Dropout(0.2),  # Dropout layer with a dropout rate of 20%
    Dense(16, activation='relu'),  # Additional hidden layer
    Dense(1)  # Output layer for regression
])

# Compile the model
ann.compile(loss='mean_squared_error',
        optimizer=RMSprop(learning_rate=0.005, rho=0.9, momentum=0.0, epsilon=1e-07, weight_decay=0.0,),
        metrics=[metrics.mae])

# %% [markdown]
# In the neural network architecture for regression, I've used the following components:
#
# **Activation Function:** ReLU is employed in the hidden layers to introduce non-linearity into the model.
#
# **Dropout:** I applied a dropout rate of 20% to the second hidden layer. During training, approximately 20% of the neurons in this layer are randomly deactivated for each batch. This helps prevent overfitting by adding noise and reducing reliance on specific neurons.
#
# **Optimizer:** I chose RMSprop as the optimization algorithm. It's a variant of gradient descent that adapts the learning rate for each parameter during training. My configuration includes a learning rate of 0.005, no momentum effect, epsilon set to 1e-07, and no weight decay.
#
# **Loss Function:** For this regression task, I opted for Mean Squared Error (MSE), which measures the average squared difference between the predicted values and the actual target values.
# Metric: In addition to MSE, I use Mean Absolute Error (MAE) as a metric to evaluate the model's performance.
#
# **Regarding hyperparameters:**
#
# **Learning Rate:** I set the learning rate to 0.005, striking a balance between training speed and convergence. The learning rate determines the step size during weight updates in optimization.
#
# **Momentum:** In this model, I chose a momentum value of 0.0, meaning there's no momentum effect. Each weight update is solely determined by the current gradient. Momentum can accelerate convergence by smoothing weight updates but wasn't used here.
#
# **Epsilon:** Epsilon (ε) was set to 1e-07 to ensure numerical stability during optimization. It's particularly important when dealing with small gradient values.
#
# **Weight Decay:** I didn't apply weight decay (L2 regularization) in this model. Weight decay adds a penalty term based on weight magnitudes to prevent overfitting. However, in this case, I relied on other regularization techniques.

# %%
ann.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               2000
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_2 (Dense)             (None, 16)                816
#
#  dense_3 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 7,883
# Trainable params: 7,883
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Model Architechture**
#
# **Hidden Layer 1 (Dense - "dense"):**
# Output Shape: (None, 100)
# Trainable Parameters: 19 (input features) * 100 (neurons) + 100 (biases) = 2000
#
# **Hidden Layer 2 (Dense - "dense_1"):**
# Output Shape: (None, 50)
# Trainable Parameters: 100 (previous layer output) * 50 (neurons) + 50 (biases) = 2080
#
# **Dropout Layer ("dropout"):**
# Output Shape: (None, 50)
# No trainable parameters (0).
#
# **Hidden Layer 3 (Dense - "dense_2"):**
# Output Shape: (None, 16)
# Trainable Parameters: 50 (previous layer output) * 16 (neurons) + 16 (biases) = 528
#
# **Output Layer (Dense - "dense_3"):**
# Output Shape: (None, 1)
# Trainable Parameters: 16 (previous layer output) * 1 (neuron) + 1 (bias) = 17
# Total Trainable Parameters: 1280 + 2080 + 528 + 17 = 3905.

# %% [markdown]
# ####**Model Training**

# %% [markdown]
# EarlyStopping callback is used from Keras to stop the model training if the validation loss stops decreasing for a few epochs (Here, after 10 epochs).

# %%
# Import the EarlyStopping callback from Keras
from tensorflow.keras.callbacks import EarlyStopping

# Create an EarlyStopping callback with 'val_loss' as the monitor and patience set to 10
escb = EarlyStopping(monitor='val_loss', patience=10)

# Train the neural network model 'ann'
history = ann.fit(
    X_train,               # Training data features
    y_train,               # Training data labels
    batch_size=64,         # Batch size for training
    epochs=100,            # Number of training epochs
    shuffle=True,          # Shuffle the training data before each epoch
    verbose=2,             # Verbosity level for training output
    validation_data=(X_test, y_test),  # Validation data
    callbacks=[escb]       # List of callbacks, including EarlyStopping
)
# Out:
# Epoch 1/100
# 237/237 - 5s - loss: 335465021440.0000 - mean_absolute_error: 436512.0938 - val_loss: 107129667584.0000 - val_mean_absolute_error: 189826.6875 - 5s/epoch - 19ms/step
# Epoch 2/100
# 237/237 - 1s - loss: 105324380160.0000 - mean_absolute_error: 201394.9062 - val_loss: 80309600256.0000 - val_mean_absolute_error: 184573.5156 - 1s/epoch - 5ms/step
# Epoch 3/100
# 237/237 - 1s - loss: 88341348352.0000 - mean_absolute_error: 185572.9531 - val_loss: 66043400192.0000 - val_mean_absolute_error: 166755.0625 - 1s/epoch - 5ms/step
# Epoch 4/100
# 237/237 - 1s - loss: 72144781312.0000 - mean_absolute_error: 163325.3594 - val_loss: 52695695360.0000 - val_mean_absolute_error: 142172.3594 - 1s/epoch - 5ms/step
# Epoch 5/100
# 237/237 - 1s - loss: 61321003008.0000 - mean_absolute_error: 147302.8906 - val_loss: 47234646016.0000 - val_mean_absolute_error: 131603.9062 - 1s/epoch - 5ms/step
# Epoch 6/100
# 237/237 - 1s - loss: 56767725568.0000 - mean_absolute_error: 143872.6250 - val_loss: 45543616512.0000 - val_mean_absolute_error: 127749.6641 - 1s/epoch - 5ms/step
# Epoch 7/100
# 237/237 - 2s - loss: 53949038592.0000 - mean_absolute_error: 139792.9844 - val_loss: 42927243264.0000 - val_mean_absolute_error: 127508.4453 - 2s/epoch - 7ms/step
# Epoch 8/100
# 237/237 - 2s - loss: 52272717824.0000 - mean_absolute_error: 137969.9062 - val_loss: 41543602176.0000 - val_mean_absolute_error: 125196.0234 - 2s/epoch - 9ms/step
# Epoch 9/100
# 237/237 - 1s - loss: 50983772160.0000 - mean_absolute_error: 137810.4688 - val_loss: 40779866112.0000 - val_mean_absolute_error: 128742.0078 - 1s/epoch - 5ms/step
# Epoch 10/100
# 237/237 - 2s - loss: 48665894912.0000 - mean_absolute_error: 136192.4219 - val_loss: 39347548160.0000 - val_mean_absolute_error: 120846.9062 - 2s/epoch - 8ms/step
# Epoch 11/100
# 237/237 - 1s - loss: 47150325760.0000 - mean_absolute_error: 134272.8750 - val_loss: 38045298688.0000 - val_mean_absolute_error: 121651.8984 - 1s/epoch - 5ms/step
# Epoch 12/100
# 237/237 - 1s - loss: 46886260736.0000 - mean_absolute_error: 133237.3125 - val_loss: 37397577728.0000 - val_mean_absolute_error: 119963.1250 - 1s/epoch - 5ms/step
# Epoch 13/100
# 237/237 - 1s - loss: 46196322304.0000 - mean_absolute_error: 132288.8906 - val_loss: 36593430528.0000 - val_mean_absolute_error: 118869.0156 - 1s/epoch - 5ms/step
# Epoch 14/100
# 237/237 - 2s - loss: 44573810688.0000 - mean_absolute_error: 130660.6953 - val_loss: 36071616512.0000 - val_mean_absolute_error: 118394.4531 - 2s/epoch - 6ms/step
# Epoch 15/100
# 237/237 - 1s - loss: 43804909568.0000 - mean_absolute_error: 129377.9766 - val_loss: 35541954560.0000 - val_mean_absolute_error: 120012.6250 - 1s/epoch - 5ms/step
# Epoch 16/100
# 237/237 - 2s - loss: 43065548800.0000 - mean_absolute_error: 128448.2734 - val_loss: 34645495808.0000 - val_mean_absolute_error: 117778.8203 - 2s/epoch - 7ms/step
# Epoch 17/100
# 237/237 - 2s - loss: 42301448192.0000 - mean_absolute_error: 126703.5547 - val_loss: 34118731776.0000 - val_mean_absolute_error: 116329.2578 - 2s/epoch - 8ms/step
# Epoch 18/100
# 237/237 - 1s - loss: 41281937408.0000 - mean_absolute_error: 126427.4219 - val_loss: 33977300992.0000 - val_mean_absolute_error: 114714.7812 - 1s/epoch - 6ms/step
# Epoch 19/100
# 237/237 - 1s - loss: 41471016960.0000 - mean_absolute_error: 125723.2422 - val_loss: 33314500608.0000 - val_mean_absolute_error: 115171.6016 - 1s/epoch - 5ms/step
# Epoch 20/100
# 237/237 - 1s - loss: 41091112960.0000 - mean_absolute_error: 125392.8828 - val_loss: 33028558848.0000 - val_mean_absolute_error: 113691.4141 - 625ms/epoch - 3ms/step
# Epoch 21/100
# 237/237 - 1s - loss: 40327503872.0000 - mean_absolute_error: 125004.1016 - val_loss: 32649265152.0000 - val_mean_absolute_error: 113737.5078 - 589ms/epoch - 2ms/step
# Epoch 22/100
# 237/237 - 1s - loss: 40311062528.0000 - mean_absolute_error: 124392.0547 - val_loss: 33598859264.0000 - val_mean_absolute_error: 118917.5703 - 532ms/epoch - 2ms/step
# Epoch 23/100
# 237/237 - 1s - loss: 39749709824.0000 - mean_absolute_error: 123668.5234 - val_loss: 32172816384.0000 - val_mean_absolute_error: 112546.1875 - 529ms/epoch - 2ms/step
# Epoch 24/100
# 237/237 - 1s - loss: 38818721792.0000 - mean_absolute_error: 122983.8594 - val_loss: 31973314560.0000 - val_mean_absolute_error: 112300.2266 - 588ms/epoch - 2ms/step
# Epoch 25/100
# 237/237 - 1s - loss: 38516633600.0000 - mean_absolute_error: 122616.1250 - val_loss: 31692384256.0000 - val_mean_absolute_error: 112129.3828 - 589ms/epoch - 2ms/step
# Epoch 26/100
# 237/237 - 1s - loss: 38704934912.0000 - mean_absolute_error: 121227.6328 - val_loss: 31519420416.0000 - val_mean_absolute_error: 111881.5547 - 596ms/epoch - 3ms/step
# Epoch 27/100
# 237/237 - 1s - loss: 38581055488.0000 - mean_absolute_error: 121458.8047 - val_loss: 31306268672.0000 - val_mean_absolute_error: 110511.0312 - 609ms/epoch - 3ms/step
# Epoch 28/100
# 237/237 - 1s - loss: 38439940096.0000 - mean_absolute_error: 121237.9141 - val_loss: 31417636864.0000 - val_mean_absolute_error: 109896.3906 - 581ms/epoch - 2ms/step
# Epoch 29/100
# 237/237 - 1s - loss: 37434159104.0000 - mean_absolute_error: 120382.3750 - val_loss: 31019292672.0000 - val_mean_absolute_error: 110721.2422 - 1s/epoch - 4ms/step
# Epoch 30/100
# 237/237 - 1s - loss: 37474627584.0000 - mean_absolute_error: 120157.8672 - val_loss: 30699812864.0000 - val_mean_absolute_error: 109704.3281 - 1s/epoch - 6ms/step
# Epoch 31/100
# 237/237 - 2s - loss: 37213282304.0000 - mean_absolute_error: 120055.3750 - val_loss: 30823024640.0000 - val_mean_absolute_error: 108946.2969 - 2s/epoch - 10ms/step
# Epoch 32/100
# 237/237 - 2s - loss: 37325971456.0000 - mean_absolute_error: 119331.9922 - val_loss: 30417283072.0000 - val_mean_absolute_error: 109458.5000 - 2s/epoch - 7ms/step
# Epoch 33/100
# 237/237 - 1s - loss: 37040238592.0000 - mean_absolute_error: 118755.5781 - val_loss: 30271205376.0000 - val_mean_absolute_error: 109104.3438 - 1s/epoch - 5ms/step
# Epoch 34/100
# 237/237 - 1s - loss: 36798337024.0000 - mean_absolute_error: 118830.7109 - val_loss: 30229989376.0000 - val_mean_absolute_error: 108616.2188 - 1s/epoch - 5ms/step
# Epoch 35/100
# 237/237 - 1s - loss: 36674285568.0000 - mean_absolute_error: 118648.4688 - val_loss: 30372952064.0000 - val_mean_absolute_error: 110194.5078 - 1s/epoch - 5ms/step
# Epoch 36/100
# 237/237 - 2s - loss: 36013400064.0000 - mean_absolute_error: 117976.7031 - val_loss: 30000562176.0000 - val_mean_absolute_error: 108213.9688 - 2s/epoch - 7ms/step
# Epoch 37/100
# 237/237 - 1s - loss: 36915699712.0000 - mean_absolute_error: 118491.4688 - val_loss: 30011590656.0000 - val_mean_absolute_error: 108367.2266 - 1s/epoch - 4ms/step
# Epoch 38/100
# 237/237 - 1s - loss: 36659449856.0000 - mean_absolute_error: 117940.2031 - val_loss: 29885028352.0000 - val_mean_absolute_error: 107235.2969 - 1s/epoch - 5ms/step
# Epoch 39/100
# 237/237 - 1s - loss: 36544086016.0000 - mean_absolute_error: 117554.8828 - val_loss: 29829566464.0000 - val_mean_absolute_error: 107529.4141 - 1s/epoch - 5ms/step
# Epoch 40/100
# 237/237 - 2s - loss: 37366591488.0000 - mean_absolute_error: 118240.7500 - val_loss: 29601415168.0000 - val_mean_absolute_error: 107813.1953 - 2s/epoch - 7ms/step
# Epoch 41/100
# 237/237 - 2s - loss: 36800733184.0000 - mean_absolute_error: 117428.5078 - val_loss: 29606488064.0000 - val_mean_absolute_error: 108024.9297 - 2s/epoch - 8ms/step
# Epoch 42/100
# 237/237 - 2s - loss: 36258062336.0000 - mean_absolute_error: 117426.1484 - val_loss: 29871923200.0000 - val_mean_absolute_error: 109671.5391 - 2s/epoch - 7ms/step
# Epoch 43/100
# 237/237 - 2s - loss: 35645452288.0000 - mean_absolute_error: 117185.2344 - val_loss: 29492609024.0000 - val_mean_absolute_error: 106552.1016 - 2s/epoch - 6ms/step
# Epoch 44/100
# 237/237 - 1s - loss: 35565740032.0000 - mean_absolute_error: 117051.9062 - val_loss: 29250617344.0000 - val_mean_absolute_error: 106659.7578 - 1s/epoch - 6ms/step
# Epoch 45/100
# 237/237 - 1s - loss: 35724009472.0000 - mean_absolute_error: 116319.1016 - val_loss: 29157210112.0000 - val_mean_absolute_error: 106930.8203 - 1s/epoch - 5ms/step
# Epoch 46/100
# 237/237 - 1s - loss: 36140888064.0000 - mean_absolute_error: 116028.7656 - val_loss: 29147557888.0000 - val_mean_absolute_error: 106892.3203 - 819ms/epoch - 3ms/step
# Epoch 47/100
# 237/237 - 1s - loss: 35419680768.0000 - mean_absolute_error: 116248.6016 - val_loss: 29589938176.0000 - val_mean_absolute_error: 109651.1562 - 1s/epoch - 4ms/step
# Epoch 48/100
# 237/237 - 2s - loss: 36055621632.0000 - mean_absolute_error: 116762.5938 - val_loss: 29035771904.0000 - val_mean_absolute_error: 106424.0703 - 2s/epoch - 7ms/step
# Epoch 49/100
# 237/237 - 2s - loss: 34950156288.0000 - mean_absolute_error: 115726.5547 - val_loss: 28929654784.0000 - val_mean_absolute_error: 106707.1484 - 2s/epoch - 7ms/step
# Epoch 50/100
# 237/237 - 1s - loss: 35601829888.0000 - mean_absolute_error: 116940.8984 - val_loss: 30006102016.0000 - val_mean_absolute_error: 105917.4375 - 927ms/epoch - 4ms/step
# Epoch 51/100
# 237/237 - 1s - loss: 35386466304.0000 - mean_absolute_error: 116263.5938 - val_loss: 29242077184.0000 - val_mean_absolute_error: 105873.3203 - 710ms/epoch - 3ms/step
# Epoch 52/100
# 237/237 - 1s - loss: 36003696640.0000 - mean_absolute_error: 116196.7578 - val_loss: 28739313664.0000 - val_mean_absolute_error: 105684.9531 - 550ms/epoch - 2ms/step
# Epoch 53/100
# 237/237 - 1s - loss: 34896678912.0000 - mean_absolute_error: 115394.0703 - val_loss: 28828581888.0000 - val_mean_absolute_error: 105723.0547 - 529ms/epoch - 2ms/step
# Epoch 54/100
# 237/237 - 1s - loss: 34893135872.0000 - mean_absolute_error: 115731.4219 - val_loss: 29275142144.0000 - val_mean_absolute_error: 109078.4062 - 568ms/epoch - 2ms/step
# Epoch 55/100
# 237/237 - 1s - loss: 35267944448.0000 - mean_absolute_error: 116068.5234 - val_loss: 28585105408.0000 - val_mean_absolute_error: 106030.1562 - 563ms/epoch - 2ms/step
# Epoch 56/100
# 237/237 - 1s - loss: 35289317376.0000 - mean_absolute_error: 115710.8516 - val_loss: 28558104576.0000 - val_mean_absolute_error: 105112.1641 - 550ms/epoch - 2ms/step
# Epoch 57/100
# 237/237 - 1s - loss: 34884567040.0000 - mean_absolute_error: 115557.8594 - val_loss: 28982206464.0000 - val_mean_absolute_error: 108104.8828 - 555ms/epoch - 2ms/step
# Epoch 58/100
# 237/237 - 1s - loss: 34454188032.0000 - mean_absolute_error: 115280.1016 - val_loss: 28665954304.0000 - val_mean_absolute_error: 107440.7422 - 563ms/epoch - 2ms/step
# Epoch 59/100
# 237/237 - 1s - loss: 34948280320.0000 - mean_absolute_error: 114938.2656 - val_loss: 28729577472.0000 - val_mean_absolute_error: 104792.6484 - 559ms/epoch - 2ms/step
# Epoch 60/100
# 237/237 - 1s - loss: 34797854720.0000 - mean_absolute_error: 115369.2344 - val_loss: 29092941824.0000 - val_mean_absolute_error: 105221.2891 - 564ms/epoch - 2ms/step
# Epoch 61/100
# 237/237 - 1s - loss: 34648297472.0000 - mean_absolute_error: 114467.0703 - val_loss: 28182335488.0000 - val_mean_absolute_error: 105309.1016 - 599ms/epoch - 3ms/step
# Epoch 62/100
# 237/237 - 1s - loss: 34682081280.0000 - mean_absolute_error: 114751.7734 - val_loss: 28269168640.0000 - val_mean_absolute_error: 104749.6484 - 556ms/epoch - 2ms/step
# Epoch 63/100
# 237/237 - 1s - loss: 34036396032.0000 - mean_absolute_error: 114568.8984 - val_loss: 28202295296.0000 - val_mean_absolute_error: 104696.6250 - 575ms/epoch - 2ms/step
# Epoch 64/100
# 237/237 - 1s - loss: 35391918080.0000 - mean_absolute_error: 115851.1172 - val_loss: 28089712640.0000 - val_mean_absolute_error: 105439.7891 - 524ms/epoch - 2ms/step
# Epoch 65/100
# 237/237 - 1s - loss: 33907318784.0000 - mean_absolute_error: 114480.6641 - val_loss: 28328839168.0000 - val_mean_absolute_error: 107402.6875 - 553ms/epoch - 2ms/step
# Epoch 66/100
# 237/237 - 1s - loss: 34201757696.0000 - mean_absolute_error: 114034.5625 - val_loss: 27955253248.0000 - val_mean_absolute_error: 104750.0781 - 518ms/epoch - 2ms/step
# Epoch 67/100
# 237/237 - 1s - loss: 33794965504.0000 - mean_absolute_error: 114264.2344 - val_loss: 28137492480.0000 - val_mean_absolute_error: 104533.7578 - 549ms/epoch - 2ms/step
# Epoch 68/100
# 237/237 - 1s - loss: 33832507392.0000 - mean_absolute_error: 114333.2969 - val_loss: 27926282240.0000 - val_mean_absolute_error: 104313.3672 - 562ms/epoch - 2ms/step
# Epoch 69/100
# 237/237 - 1s - loss: 34413117440.0000 - mean_absolute_error: 114272.5859 - val_loss: 27793324032.0000 - val_mean_absolute_error: 104429.1094 - 889ms/epoch - 4ms/step
# Epoch 70/100
# 237/237 - 1s - loss: 34278750208.0000 - mean_absolute_error: 114124.2500 - val_loss: 27806396416.0000 - val_mean_absolute_error: 104307.2188 - 942ms/epoch - 4ms/step
# Epoch 71/100
# 237/237 - 1s - loss: 33932062720.0000 - mean_absolute_error: 113806.6094 - val_loss: 27779301376.0000 - val_mean_absolute_error: 103845.1406 - 814ms/epoch - 3ms/step
# Epoch 72/100
# 237/237 - 1s - loss: 33796081664.0000 - mean_absolute_error: 113899.7656 - val_loss: 28581974016.0000 - val_mean_absolute_error: 104324.0078 - 536ms/epoch - 2ms/step
# Epoch 73/100
# 237/237 - 1s - loss: 33084272640.0000 - mean_absolute_error: 113055.7969 - val_loss: 27798534144.0000 - val_mean_absolute_error: 103895.7500 - 520ms/epoch - 2ms/step
# Epoch 74/100
# 237/237 - 1s - loss: 33013657600.0000 - mean_absolute_error: 112726.9531 - val_loss: 27759704064.0000 - val_mean_absolute_error: 105021.4609 - 553ms/epoch - 2ms/step
# Epoch 75/100
# 237/237 - 1s - loss: 33395124224.0000 - mean_absolute_error: 113404.9609 - val_loss: 27584131072.0000 - val_mean_absolute_error: 104086.5625 - 532ms/epoch - 2ms/step
# Epoch 76/100
# 237/237 - 1s - loss: 34169683968.0000 - mean_absolute_error: 114454.8203 - val_loss: 27657748480.0000 - val_mean_absolute_error: 105294.3984 - 551ms/epoch - 2ms/step
# Epoch 77/100
# 237/237 - 1s - loss: 32766801920.0000 - mean_absolute_error: 112471.8438 - val_loss: 27785625600.0000 - val_mean_absolute_error: 103424.5547 - 1s/epoch - 5ms/step
# Epoch 78/100
# 237/237 - 1s - loss: 33695195136.0000 - mean_absolute_error: 113861.8281 - val_loss: 28852404224.0000 - val_mean_absolute_error: 103794.1328 - 1s/epoch - 4ms/step
# Epoch 79/100
# 237/237 - 1s - loss: 32512014336.0000 - mean_absolute_error: 112195.6953 - val_loss: 27321290752.0000 - val_mean_absolute_error: 103445.8125 - 1s/epoch - 5ms/step
# Epoch 80/100
# 237/237 - 1s - loss: 34021998592.0000 - mean_absolute_error: 113430.7266 - val_loss: 27254067200.0000 - val_mean_absolute_error: 104117.3438 - 975ms/epoch - 4ms/step
# Epoch 81/100
# 237/237 - 1s - loss: 33893971968.0000 - mean_absolute_error: 113508.4375 - val_loss: 27375650816.0000 - val_mean_absolute_error: 102926.0547 - 1s/epoch - 5ms/step
# Epoch 82/100
# 237/237 - 1s - loss: 32362811392.0000 - mean_absolute_error: 112228.3359 - val_loss: 27463317504.0000 - val_mean_absolute_error: 102956.8438 - 1s/epoch - 5ms/step
# Epoch 83/100
# 237/237 - 1s - loss: 33433829376.0000 - mean_absolute_error: 113088.5703 - val_loss: 27143354368.0000 - val_mean_absolute_error: 102825.8438 - 1s/epoch - 6ms/step
# Epoch 84/100
# 237/237 - 2s - loss: 33525966848.0000 - mean_absolute_error: 113135.3984 - val_loss: 27182016512.0000 - val_mean_absolute_error: 102656.1016 - 2s/epoch - 8ms/step
# Epoch 85/100
# 237/237 - 2s - loss: 32178839552.0000 - mean_absolute_error: 112659.7031 - val_loss: 27028387840.0000 - val_mean_absolute_error: 103865.5469 - 2s/epoch - 6ms/step
# Epoch 86/100
# 237/237 - 1s - loss: 32300791808.0000 - mean_absolute_error: 112091.8750 - val_loss: 26961563648.0000 - val_mean_absolute_error: 102750.7188 - 1s/epoch - 4ms/step
# Epoch 87/100
# 237/237 - 1s - loss: 32531509248.0000 - mean_absolute_error: 111876.0234 - val_loss: 27226441728.0000 - val_mean_absolute_error: 102310.7734 - 893ms/epoch - 4ms/step
# Epoch 88/100
# 237/237 - 1s - loss: 32926732288.0000 - mean_absolute_error: 112489.9844 - val_loss: 26919813120.0000 - val_mean_absolute_error: 102388.1094 - 1s/epoch - 5ms/step
# Epoch 89/100
# 237/237 - 1s - loss: 33234692096.0000 - mean_absolute_error: 112537.0234 - val_loss: 26826364928.0000 - val_mean_absolute_error: 102462.5625 - 1s/epoch - 5ms/step
# Epoch 90/100
# 237/237 - 1s - loss: 32534636544.0000 - mean_absolute_error: 112146.2266 - val_loss: 27235049472.0000 - val_mean_absolute_error: 102449.3047 - 946ms/epoch - 4ms/step
# Epoch 91/100
# 237/237 - 1s - loss: 32659046400.0000 - mean_absolute_error: 112005.2422 - val_loss: 26735968256.0000 - val_mean_absolute_error: 102061.0781 - 994ms/epoch - 4ms/step
# Epoch 92/100
# 237/237 - 1s - loss: 32612884480.0000 - mean_absolute_error: 111687.0781 - val_loss: 27053273088.0000 - val_mean_absolute_error: 101843.5312 - 1s/epoch - 4ms/step
# Epoch 93/100
# 237/237 - 1s - loss: 32778856448.0000 - mean_absolute_error: 111719.2188 - val_loss: 26738931712.0000 - val_mean_absolute_error: 101782.4141 - 755ms/epoch - 3ms/step
# Epoch 94/100
# 237/237 - 1s - loss: 32984694784.0000 - mean_absolute_error: 112375.4297 - val_loss: 29155807232.0000 - val_mean_absolute_error: 105357.8594 - 551ms/epoch - 2ms/step
# Epoch 95/100
# 237/237 - 1s - loss: 32319420416.0000 - mean_absolute_error: 111821.4375 - val_loss: 26715406336.0000 - val_mean_absolute_error: 101989.2031 - 919ms/epoch - 4ms/step
# Epoch 96/100
# 237/237 - 2s - loss: 33035427840.0000 - mean_absolute_error: 111795.7344 - val_loss: 26607720448.0000 - val_mean_absolute_error: 103064.7031 - 2s/epoch - 8ms/step
# Epoch 97/100
# 237/237 - 1s - loss: 32091281408.0000 - mean_absolute_error: 110947.6172 - val_loss: 26660980736.0000 - val_mean_absolute_error: 101641.5156 - 743ms/epoch - 3ms/step
# Epoch 98/100
# 237/237 - 1s - loss: 32011405312.0000 - mean_absolute_error: 111171.1328 - val_loss: 27356784640.0000 - val_mean_absolute_error: 101805.5156 - 801ms/epoch - 3ms/step
# Epoch 99/100
# 237/237 - 1s - loss: 32119312384.0000 - mean_absolute_error: 111058.2891 - val_loss: 26326784000.0000 - val_mean_absolute_error: 102728.8359 - 997ms/epoch - 4ms/step
# Epoch 100/100
# 237/237 - 1s - loss: 31662123008.0000 - mean_absolute_error: 110957.5859 - val_loss: 26546798592.0000 - val_mean_absolute_error: 101394.6953 - 1s/epoch - 4ms/step

# %% [markdown]
# ####Model Evaluation

# %%
# Evaluate model
train_score = ann.evaluate(X_train, y_train, verbose=0)
valid_score = ann.evaluate(X_test, y_test, verbose=0)

# Train metrics
mae_train = round(train_score[1], 2)
mse_train = round(train_score[0], 2)
rmse_train = round(np.sqrt(train_score[0]), 2)  # Calculate RMSE from MSE

# Validation metrics
mae_valid = round(valid_score[1], 2)
mse_valid = round(valid_score[0], 2)
rmse_valid = round(np.sqrt(valid_score[0]), 2)  # Calculate RMSE from MSE

# Print metrics
print('ANN Train MAE:', mae_train)
print('ANN Train MSE:', mse_train)
print('ANN Train RMSE:', rmse_train)
print('ANN Validation MAE:', mae_valid)
print('ANN Validation MSE:', mse_valid)
print('ANN Validation RMSE:', rmse_valid)
# Out:
# ANN Train MAE: 102880.39
# ANN Train MSE: 28987170816.0
# ANN Train RMSE: 170256.19
# ANN Validation MAE: 101394.77
# ANN Validation MSE: 26546800640.0
# ANN Validation RMSE: 162931.89

# %% [markdown]
# ####Model Prediction

# %%
y_valid_pred = ann.predict(X_test)
# Plot
plt.scatter(y_test, y_valid_pred)
plt.ylabel('y_test')
plt.xlabel('y_valid_pred')
plt.show()

shape_y_test = y_test.shape
shape_y_valid_pred = y_valid_pred.shape

# Print the shapes
print("Shape of y_test:", shape_y_test)
print("Shape of y_valid_pred:", shape_y_valid_pred)

# Calculate the correlation coefficient
corr_result = np.corrcoef(y_test, y_valid_pred[:, 0])

# Extract the correlation coefficient from the result
correlation_coefficient = corr_result[0, 1]

# Print the correlation coefficient
print('The Correlation between y_test and y_valid_pred is:', round(correlation_coefficient, 3))
# Out:
# 203/203 [==============================] - 0s 1ms/step
# Shape of y_test: (6484,)
# Shape of y_valid_pred: (6484, 1)
# The Correlation between y_test and y_valid_pred is: 0.887

# %% [markdown]
# ####Plotting Training and Validation Loss

# %%
def plot_hist(h, xsize=6, ysize=5):
    # Prepare plotting
    fig_size = plt.rcParams["figure.figsize"]
    plt.rcParams["figure.figsize"] = [xsize, ysize]

    # Get training and validation keys
    ks = list(h.keys())
    n2 = math.floor(len(ks)/2)
    train_keys = ks[0:n2]
    valid_keys = ks[n2:2*n2]

    # summarize history for different metrics
    for i in range(n2):
        plt.plot(h[train_keys[i]])
        plt.plot(h[valid_keys[i]])
        plt.title('Training vs Validation '+train_keys[i])
        plt.ylabel(train_keys[i])
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.draw()
        plt.show()

    return

# %%
# Create a DataFrame with training and validation loss values
hist = pd.DataFrame(history.history)

# Plot history
plot_hist(hist, xsize=6, ysize=4)

# %% [markdown]
# ###Classification

# %% [markdown]
# In this section, we will transform the 'price' attribute from a numeric format into a nominal one. Specifically, houses with a price of 450,000 or more will be categorized as 'HighPrice' and less than 450,000 will be categorized as 'LowPrice.' This transformation allows us to explore and analyze the data in a more categorical context, which can be valuable for various analytical purposes such as classification modelling.

# %%
# Define the threshold price for categorization
threshold_price = 450000

# Define a function to categorize prices
def categorize_price(price):
    return 'High_Price' if price >= threshold_price else 'Low_Price'

# Apply the categorize_price function to create a new column 'price_category'
house_price_data['price_category'] = house_price_data['price'].apply(categorize_price)

# Drop the 'price' column from the DataFrame
house_price_data.drop(columns=['price'], inplace=True)

# Display the updated DataFrame with the 'price_category' column
house_price_data.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  month  year price_category
# 0  47.5112 -122.257           1340        5650     10  2014      Low_Price
# 1  47.7210 -122.319           1690        7639     12  2014     High_Price
# 2  47.7379 -122.233           2720        8062      2  2015      Low_Price
# 3  47.5208 -122.393           1360        5000     12  2014     High_Price
# 4  47.6168 -122.045           1800        7503      2  2015     High_Price

# %% [markdown]
# We are mapping the 'High_Price' category to 1 and the 'Low_Price' category to 0 in the 'price_category' column.
#
# After mapping the categories to numeric values, we convert the entire 'price_category' column to the integer data type to ensure that it contains numerical values.

# %%
# Convert 'High_Price' to 1 and 'Low_Price' to 0 in the 'price_category' column
house_price_data['price_category'][house_price_data['price_category'] == 'High_Price'] = 1
house_price_data['price_category'][house_price_data['price_category'] == 'Low_Price'] = 0

# Convert the 'price_category' column to integer data type
house_price_data['price_category'] = house_price_data['price_category'].astype(int)
# Out:
# <ipython-input-25-7686035043d8>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_price_data['price_category'][house_price_data['price_category'] == 'High_Price'] = 1
# <ipython-input-25-7686035043d8>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   house_price_data['price_category'][house_price_data['price_category'] == 'Low_Price'] = 0

# %%
#View binary price category
house_price_data.head()
# Out:
#    bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  view  \
# 0         3       1.00         1180      5650     1.0           0     0
# 1         3       2.25         2570      7242     2.0           0     0
# 2         2       1.00          770     10000     1.0           0     0
# 3         4       3.00         1960      5000     1.0           0     0
# 4         3       2.00         1680      8080     1.0           0     0
#
#    condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0          3      7        1180              0      1955             0
# 1          3      7        2170            400      1951          1991
# 2          3      6         770              0      1933             0
# 3          5      7        1050            910      1965             0
# 4          3      8        1680              0      1987             0
#
#        lat     long  sqft_living15  sqft_lot15  month  year  price_category
# 0  47.5112 -122.257           1340        5650     10  2014               0
# 1  47.7210 -122.319           1690        7639     12  2014               1
# 2  47.7379 -122.233           2720        8062      2  2015               0
# 3  47.5208 -122.393           1360        5000     12  2014               1
# 4  47.6168 -122.045           1800        7503      2  2015               1

# %% [markdown]
# ####Train Test Split

# %% [markdown]
# The dataset is split into training and testing sets using train_test_split with a test size of 30% and a specified random state (2023) for reproducibility.

# %%
label = house_price_data['price_category']

# Splitting the dataset into training and testing sets
price_X_train, price_X_test, price_y_train, price_y_test = train_test_split(X_scale, label, test_size=0.3, random_state=2023) # using a random state for reproducibility

# Print the minimum and maximum values of the training set
print('X train min =', round(price_X_train.min().min(), 4), '; max =', round(price_X_train.max().max(), 4))

# Print the minimum and maximum values of the testing set
print('X valid min =', round(price_X_test.min().min(), 4), '; max =', round(price_X_test.max().max(), 4))
# Out:
# X train min = 0.0 ; max = 1.0
# X valid min = 0.0 ; max = 1.0

# %% [markdown]
# One-hot encoding is required for neural networks to represent categorical data as binary vectors. It ensures that neural networks can process categorical variables, handle multi-class problems, and make predictions without making incorrect ordinal assumptions about the data.

# %%
# Convert binary labels to one-hot encoding
from keras.utils import to_categorical

# Convert training and testing labels to one-hot encoding
y_train_one_hot = to_categorical(price_y_train, num_classes=2)
y_test_one_hot = to_categorical(price_y_test, num_classes=2)

# Print the shapes of the training and testing data and labels
print('Train shape: x=', price_X_train.shape, ', y=', y_train_one_hot.shape)
print('Test shape: x=', price_X_test.shape, ', y=', y_test_one_hot.shape)
# Out:
# Train shape: x= (15129, 19) , y= (15129, 2)
# Test shape: x= (6484, 19) , y= (6484, 2)

# %% [markdown]
# ####Neural Network Model Building

# %% [markdown]
# I've designed a neural network model for a binary classification task with the following architecture:
#
# Input Layer: 64 neurons using ReLU activation, taking input shape based on the number of features.
#
# Dropout Layer: Incorporating 30% dropout to prevent overfitting.
#
# Hidden Layer: 32 neurons with ReLU activation.
#
# Output Layer: 2 neurons employing softmax activation for binary classification. Softmax is commonly used for the output layer in multi-class classification problems, including binary classification.
#
# For optimization and training, I've selected the Adam optimizer. Adam adapts the learning rate during training, making it efficient and effective in various deep learning tasks.
#
# Additionally, I'm using categorical cross-entropy as the loss function to train the model, which is suitable for multi-class classification problems, including binary classification.
#
# During training, the model will be evaluated based on accuracy, providing insights into its performance.

# %%
# Define the neural network model
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dropout(0.3),  # Add Dropout
    Dense(32, activation='relu'),
    Dense(2, activation='softmax')  # Output layer with 2 classes and softmax activation
])

# Compile the model with an appropriate optimizer and loss function
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 64)                1280
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 3,426
# Trainable params: 3,426
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ####Model Training

# %%
from tensorflow.keras.callbacks import EarlyStopping
# Train the model with early stopping
history = model.fit(
    price_X_train, y_train_one_hot,
    batch_size=64,
    epochs=100,
    shuffle=True,
    verbose=2,
    validation_data=(price_X_test, y_test_one_hot),
    callbacks=[EarlyStopping(patience=10, restore_best_weights=True)]
)
# Out:
# Epoch 1/100
# 237/237 - 4s - loss: 0.5292 - accuracy: 0.7318 - val_loss: 0.3949 - val_accuracy: 0.8182 - 4s/epoch - 19ms/step
# Epoch 2/100
# 237/237 - 1s - loss: 0.4057 - accuracy: 0.8067 - val_loss: 0.3525 - val_accuracy: 0.8424 - 942ms/epoch - 4ms/step
# Epoch 3/100
# 237/237 - 1s - loss: 0.3748 - accuracy: 0.8235 - val_loss: 0.3383 - val_accuracy: 0.8473 - 965ms/epoch - 4ms/step
# Epoch 4/100
# 237/237 - 1s - loss: 0.3549 - accuracy: 0.8352 - val_loss: 0.3198 - val_accuracy: 0.8598 - 944ms/epoch - 4ms/step
# Epoch 5/100
# 237/237 - 1s - loss: 0.3430 - accuracy: 0.8445 - val_loss: 0.3062 - val_accuracy: 0.8644 - 835ms/epoch - 4ms/step
# Epoch 6/100
# 237/237 - 1s - loss: 0.3342 - accuracy: 0.8470 - val_loss: 0.3031 - val_accuracy: 0.8677 - 838ms/epoch - 4ms/step
# Epoch 7/100
# 237/237 - 1s - loss: 0.3223 - accuracy: 0.8528 - val_loss: 0.2918 - val_accuracy: 0.8705 - 511ms/epoch - 2ms/step
# Epoch 8/100
# 237/237 - 1s - loss: 0.3197 - accuracy: 0.8558 - val_loss: 0.2964 - val_accuracy: 0.8686 - 549ms/epoch - 2ms/step
# Epoch 9/100
# 237/237 - 0s - loss: 0.3136 - accuracy: 0.8591 - val_loss: 0.2847 - val_accuracy: 0.8758 - 492ms/epoch - 2ms/step
# Epoch 10/100
# 237/237 - 1s - loss: 0.3093 - accuracy: 0.8633 - val_loss: 0.2792 - val_accuracy: 0.8799 - 514ms/epoch - 2ms/step
# Epoch 11/100
# 237/237 - 1s - loss: 0.3003 - accuracy: 0.8681 - val_loss: 0.2676 - val_accuracy: 0.8823 - 503ms/epoch - 2ms/step
# Epoch 12/100
# 237/237 - 1s - loss: 0.3002 - accuracy: 0.8671 - val_loss: 0.2681 - val_accuracy: 0.8845 - 517ms/epoch - 2ms/step
# Epoch 13/100
# 237/237 - 1s - loss: 0.2928 - accuracy: 0.8712 - val_loss: 0.2622 - val_accuracy: 0.8888 - 630ms/epoch - 3ms/step
# Epoch 14/100
# 237/237 - 2s - loss: 0.2885 - accuracy: 0.8734 - val_loss: 0.2597 - val_accuracy: 0.8919 - 2s/epoch - 7ms/step
# Epoch 15/100
# 237/237 - 1s - loss: 0.2846 - accuracy: 0.8768 - val_loss: 0.2596 - val_accuracy: 0.8871 - 1s/epoch - 5ms/step
# Epoch 16/100
# 237/237 - 1s - loss: 0.2826 - accuracy: 0.8771 - val_loss: 0.2511 - val_accuracy: 0.8973 - 881ms/epoch - 4ms/step
# Epoch 17/100
# 237/237 - 1s - loss: 0.2794 - accuracy: 0.8789 - val_loss: 0.2493 - val_accuracy: 0.8937 - 973ms/epoch - 4ms/step
# Epoch 18/100
# 237/237 - 1s - loss: 0.2739 - accuracy: 0.8847 - val_loss: 0.2451 - val_accuracy: 0.8996 - 888ms/epoch - 4ms/step
# Epoch 19/100
# 237/237 - 1s - loss: 0.2732 - accuracy: 0.8813 - val_loss: 0.2417 - val_accuracy: 0.9018 - 734ms/epoch - 3ms/step
# Epoch 20/100
# 237/237 - 1s - loss: 0.2700 - accuracy: 0.8857 - val_loss: 0.2446 - val_accuracy: 0.8982 - 926ms/epoch - 4ms/step
# Epoch 21/100
# 237/237 - 1s - loss: 0.2695 - accuracy: 0.8820 - val_loss: 0.2495 - val_accuracy: 0.8924 - 906ms/epoch - 4ms/step
# Epoch 22/100
# 237/237 - 1s - loss: 0.2704 - accuracy: 0.8808 - val_loss: 0.2406 - val_accuracy: 0.9011 - 917ms/epoch - 4ms/step
# Epoch 23/100
# 237/237 - 1s - loss: 0.2639 - accuracy: 0.8842 - val_loss: 0.2387 - val_accuracy: 0.8990 - 936ms/epoch - 4ms/step
# Epoch 24/100
# 237/237 - 1s - loss: 0.2619 - accuracy: 0.8871 - val_loss: 0.2353 - val_accuracy: 0.9027 - 973ms/epoch - 4ms/step
# Epoch 25/100
# 237/237 - 1s - loss: 0.2620 - accuracy: 0.8873 - val_loss: 0.2392 - val_accuracy: 0.9007 - 681ms/epoch - 3ms/step
# Epoch 26/100
# 237/237 - 1s - loss: 0.2576 - accuracy: 0.8877 - val_loss: 0.2359 - val_accuracy: 0.9016 - 531ms/epoch - 2ms/step
# Epoch 27/100
# 237/237 - 1s - loss: 0.2582 - accuracy: 0.8876 - val_loss: 0.2322 - val_accuracy: 0.9053 - 739ms/epoch - 3ms/step
# Epoch 28/100
# 237/237 - 1s - loss: 0.2600 - accuracy: 0.8875 - val_loss: 0.2303 - val_accuracy: 0.9081 - 920ms/epoch - 4ms/step
# Epoch 29/100
# 237/237 - 1s - loss: 0.2555 - accuracy: 0.8891 - val_loss: 0.2311 - val_accuracy: 0.9058 - 958ms/epoch - 4ms/step
# Epoch 30/100
# 237/237 - 1s - loss: 0.2551 - accuracy: 0.8899 - val_loss: 0.2314 - val_accuracy: 0.9038 - 521ms/epoch - 2ms/step
# Epoch 31/100
# 237/237 - 1s - loss: 0.2557 - accuracy: 0.8894 - val_loss: 0.2362 - val_accuracy: 0.8991 - 566ms/epoch - 2ms/step
# Epoch 32/100
# 237/237 - 1s - loss: 0.2551 - accuracy: 0.8901 - val_loss: 0.2326 - val_accuracy: 0.9044 - 512ms/epoch - 2ms/step
# Epoch 33/100
# 237/237 - 1s - loss: 0.2519 - accuracy: 0.8907 - val_loss: 0.2296 - val_accuracy: 0.9050 - 555ms/epoch - 2ms/step
# Epoch 34/100
# 237/237 - 1s - loss: 0.2512 - accuracy: 0.8905 - val_loss: 0.2328 - val_accuracy: 0.9019 - 545ms/epoch - 2ms/step
# Epoch 35/100
# 237/237 - 1s - loss: 0.2504 - accuracy: 0.8925 - val_loss: 0.2270 - val_accuracy: 0.9082 - 546ms/epoch - 2ms/step
# Epoch 36/100
# 237/237 - 1s - loss: 0.2481 - accuracy: 0.8926 - val_loss: 0.2277 - val_accuracy: 0.9067 - 510ms/epoch - 2ms/step
# Epoch 37/100
# 237/237 - 1s - loss: 0.2502 - accuracy: 0.8911 - val_loss: 0.2256 - val_accuracy: 0.9050 - 532ms/epoch - 2ms/step
# Epoch 38/100
# 237/237 - 1s - loss: 0.2475 - accuracy: 0.8961 - val_loss: 0.2268 - val_accuracy: 0.9055 - 544ms/epoch - 2ms/step
# Epoch 39/100
# 237/237 - 1s - loss: 0.2490 - accuracy: 0.8917 - val_loss: 0.2245 - val_accuracy: 0.9093 - 561ms/epoch - 2ms/step
# Epoch 40/100
# 237/237 - 1s - loss: 0.2479 - accuracy: 0.8936 - val_loss: 0.2220 - val_accuracy: 0.9062 - 555ms/epoch - 2ms/step
# Epoch 41/100
# 237/237 - 1s - loss: 0.2465 - accuracy: 0.8924 - val_loss: 0.2230 - val_accuracy: 0.9085 - 513ms/epoch - 2ms/step
# Epoch 42/100
# 237/237 - 1s - loss: 0.2448 - accuracy: 0.8936 - val_loss: 0.2246 - val_accuracy: 0.9084 - 528ms/epoch - 2ms/step
# Epoch 43/100
# 237/237 - 1s - loss: 0.2464 - accuracy: 0.8943 - val_loss: 0.2230 - val_accuracy: 0.9070 - 526ms/epoch - 2ms/step
# Epoch 44/100
# 237/237 - 1s - loss: 0.2443 - accuracy: 0.8942 - val_loss: 0.2299 - val_accuracy: 0.9039 - 531ms/epoch - 2ms/step
# Epoch 45/100
# 237/237 - 1s - loss: 0.2432 - accuracy: 0.8956 - val_loss: 0.2214 - val_accuracy: 0.9099 - 523ms/epoch - 2ms/step
# Epoch 46/100
# 237/237 - 1s - loss: 0.2447 - accuracy: 0.8952 - val_loss: 0.2208 - val_accuracy: 0.9056 - 535ms/epoch - 2ms/step
# Epoch 47/100
# 237/237 - 1s - loss: 0.2442 - accuracy: 0.8944 - val_loss: 0.2307 - val_accuracy: 0.9001 - 502ms/epoch - 2ms/step
# Epoch 48/100
# 237/237 - 1s - loss: 0.2471 - accuracy: 0.8912 - val_loss: 0.2217 - val_accuracy: 0.9093 - 795ms/epoch - 3ms/step
# Epoch 49/100
# 237/237 - 1s - loss: 0.2422 - accuracy: 0.8943 - val_loss: 0.2193 - val_accuracy: 0.9082 - 935ms/epoch - 4ms/step
# Epoch 50/100
# 237/237 - 1s - loss: 0.2389 - accuracy: 0.8974 - val_loss: 0.2216 - val_accuracy: 0.9039 - 926ms/epoch - 4ms/step
# Epoch 51/100
# 237/237 - 1s - loss: 0.2407 - accuracy: 0.8957 - val_loss: 0.2208 - val_accuracy: 0.9076 - 542ms/epoch - 2ms/step
# Epoch 52/100
# 237/237 - 1s - loss: 0.2419 - accuracy: 0.8939 - val_loss: 0.2179 - val_accuracy: 0.9089 - 506ms/epoch - 2ms/step
# Epoch 53/100
# 237/237 - 1s - loss: 0.2413 - accuracy: 0.8947 - val_loss: 0.2194 - val_accuracy: 0.9084 - 532ms/epoch - 2ms/step
# Epoch 54/100
# 237/237 - 1s - loss: 0.2373 - accuracy: 0.8967 - val_loss: 0.2186 - val_accuracy: 0.9092 - 527ms/epoch - 2ms/step
# Epoch 55/100
# 237/237 - 1s - loss: 0.2404 - accuracy: 0.8957 - val_loss: 0.2183 - val_accuracy: 0.9087 - 523ms/epoch - 2ms/step
# Epoch 56/100
# 237/237 - 1s - loss: 0.2371 - accuracy: 0.8974 - val_loss: 0.2223 - val_accuracy: 0.9048 - 547ms/epoch - 2ms/step
# Epoch 57/100
# 237/237 - 1s - loss: 0.2382 - accuracy: 0.8991 - val_loss: 0.2220 - val_accuracy: 0.9105 - 626ms/epoch - 3ms/step
# Epoch 58/100
# 237/237 - 1s - loss: 0.2410 - accuracy: 0.8946 - val_loss: 0.2240 - val_accuracy: 0.9053 - 600ms/epoch - 3ms/step
# Epoch 59/100
# 237/237 - 1s - loss: 0.2379 - accuracy: 0.8986 - val_loss: 0.2190 - val_accuracy: 0.9102 - 781ms/epoch - 3ms/step
# Epoch 60/100
# 237/237 - 1s - loss: 0.2361 - accuracy: 0.8987 - val_loss: 0.2172 - val_accuracy: 0.9107 - 996ms/epoch - 4ms/step
# Epoch 61/100
# 237/237 - 1s - loss: 0.2351 - accuracy: 0.8987 - val_loss: 0.2170 - val_accuracy: 0.9102 - 897ms/epoch - 4ms/step
# Epoch 62/100
# 237/237 - 1s - loss: 0.2353 - accuracy: 0.8994 - val_loss: 0.2198 - val_accuracy: 0.9096 - 660ms/epoch - 3ms/step
# Epoch 63/100
# 237/237 - 1s - loss: 0.2339 - accuracy: 0.8997 - val_loss: 0.2155 - val_accuracy: 0.9121 - 654ms/epoch - 3ms/step
# Epoch 64/100
# 237/237 - 1s - loss: 0.2351 - accuracy: 0.9002 - val_loss: 0.2191 - val_accuracy: 0.9101 - 624ms/epoch - 3ms/step
# Epoch 65/100
# 237/237 - 1s - loss: 0.2340 - accuracy: 0.9011 - val_loss: 0.2194 - val_accuracy: 0.9082 - 802ms/epoch - 3ms/step
# Epoch 66/100
# 237/237 - 1s - loss: 0.2325 - accuracy: 0.9000 - val_loss: 0.2270 - val_accuracy: 0.9022 - 1s/epoch - 5ms/step
# Epoch 67/100
# 237/237 - 1s - loss: 0.2361 - accuracy: 0.8992 - val_loss: 0.2164 - val_accuracy: 0.9098 - 994ms/epoch - 4ms/step
# Epoch 68/100
# 237/237 - 1s - loss: 0.2334 - accuracy: 0.9027 - val_loss: 0.2171 - val_accuracy: 0.9098 - 935ms/epoch - 4ms/step
# Epoch 69/100
# 237/237 - 1s - loss: 0.2358 - accuracy: 0.8988 - val_loss: 0.2152 - val_accuracy: 0.9096 - 673ms/epoch - 3ms/step
# Epoch 70/100
# 237/237 - 1s - loss: 0.2328 - accuracy: 0.8989 - val_loss: 0.2138 - val_accuracy: 0.9130 - 921ms/epoch - 4ms/step
# Epoch 71/100
# 237/237 - 1s - loss: 0.2320 - accuracy: 0.8998 - val_loss: 0.2139 - val_accuracy: 0.9109 - 765ms/epoch - 3ms/step
# Epoch 72/100
# 237/237 - 1s - loss: 0.2337 - accuracy: 0.8989 - val_loss: 0.2168 - val_accuracy: 0.9098 - 651ms/epoch - 3ms/step
# Epoch 73/100
# 237/237 - 1s - loss: 0.2316 - accuracy: 0.9016 - val_loss: 0.2162 - val_accuracy: 0.9081 - 762ms/epoch - 3ms/step
# Epoch 74/100
# 237/237 - 1s - loss: 0.2292 - accuracy: 0.9023 - val_loss: 0.2170 - val_accuracy: 0.9119 - 851ms/epoch - 4ms/step
# Epoch 75/100
# 237/237 - 1s - loss: 0.2338 - accuracy: 0.9008 - val_loss: 0.2191 - val_accuracy: 0.9082 - 817ms/epoch - 3ms/step
# Epoch 76/100
# 237/237 - 1s - loss: 0.2300 - accuracy: 0.9023 - val_loss: 0.2148 - val_accuracy: 0.9122 - 963ms/epoch - 4ms/step
# Epoch 77/100
# 237/237 - 1s - loss: 0.2284 - accuracy: 0.9024 - val_loss: 0.2135 - val_accuracy: 0.9126 - 611ms/epoch - 3ms/step
# Epoch 78/100
# 237/237 - 1s - loss: 0.2307 - accuracy: 0.9013 - val_loss: 0.2200 - val_accuracy: 0.9055 - 624ms/epoch - 3ms/step
# Epoch 79/100
# 237/237 - 1s - loss: 0.2279 - accuracy: 0.9031 - val_loss: 0.2193 - val_accuracy: 0.9099 - 1s/epoch - 5ms/step
# Epoch 80/100
# 237/237 - 1s - loss: 0.2332 - accuracy: 0.9024 - val_loss: 0.2138 - val_accuracy: 0.9118 - 1s/epoch - 5ms/step
# Epoch 81/100
# 237/237 - 1s - loss: 0.2318 - accuracy: 0.8984 - val_loss: 0.2130 - val_accuracy: 0.9124 - 1s/epoch - 6ms/step
# Epoch 82/100
# 237/237 - 2s - loss: 0.2319 - accuracy: 0.8983 - val_loss: 0.2142 - val_accuracy: 0.9084 - 2s/epoch - 8ms/step
# Epoch 83/100
# 237/237 - 1s - loss: 0.2305 - accuracy: 0.9005 - val_loss: 0.2126 - val_accuracy: 0.9105 - 732ms/epoch - 3ms/step
# Epoch 84/100
# 237/237 - 1s - loss: 0.2275 - accuracy: 0.9028 - val_loss: 0.2129 - val_accuracy: 0.9104 - 1s/epoch - 4ms/step
# Epoch 85/100
# 237/237 - 1s - loss: 0.2267 - accuracy: 0.9023 - val_loss: 0.2165 - val_accuracy: 0.9107 - 1s/epoch - 5ms/step
# Epoch 86/100
# 237/237 - 1s - loss: 0.2277 - accuracy: 0.9023 - val_loss: 0.2165 - val_accuracy: 0.9115 - 1s/epoch - 4ms/step
# Epoch 87/100
# 237/237 - 1s - loss: 0.2283 - accuracy: 0.9018 - val_loss: 0.2129 - val_accuracy: 0.9095 - 1s/epoch - 6ms/step
# Epoch 88/100
# 237/237 - 1s - loss: 0.2275 - accuracy: 0.9048 - val_loss: 0.2252 - val_accuracy: 0.9042 - 1s/epoch - 5ms/step
# Epoch 89/100
# 237/237 - 1s - loss: 0.2274 - accuracy: 0.9032 - val_loss: 0.2139 - val_accuracy: 0.9113 - 1s/epoch - 5ms/step
# Epoch 90/100
# 237/237 - 1s - loss: 0.2278 - accuracy: 0.9030 - val_loss: 0.2159 - val_accuracy: 0.9113 - 1s/epoch - 4ms/step
# Epoch 91/100
# 237/237 - 1s - loss: 0.2248 - accuracy: 0.9037 - val_loss: 0.2178 - val_accuracy: 0.9095 - 1s/epoch - 5ms/step
# Epoch 92/100
# 237/237 - 2s - loss: 0.2245 - accuracy: 0.9030 - val_loss: 0.2153 - val_accuracy: 0.9112 - 2s/epoch - 8ms/step
# Epoch 93/100
# 237/237 - 1s - loss: 0.2271 - accuracy: 0.9045 - val_loss: 0.2167 - val_accuracy: 0.9110 - 1s/epoch - 5ms/step

# %% [markdown]
# ####Model Evaluation

# %%
# Evaluate the model on the training and validation datasets
train_score2 = model.evaluate(price_X_train, y_train_one_hot, verbose=0)
valid_score2 = model.evaluate(price_X_test, y_test_one_hot, verbose=0)

# Print the training accuracy and loss
print('Train Accuracy: ', round(train_score2[1], 2))
print('Train Loss: ', round(train_score2[0], 2))

# Print the validation accuracy and loss
print('Val Accuracy: ', round(valid_score2[1], 2))
print('Val Loss: ', round(valid_score2[0], 2))
# Out:
# Train Accuracy:  0.91
# Train Loss:  0.21
# Val Accuracy:  0.91
# Val Loss:  0.21

# %% [markdown]
# Model Prediction

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import cohen_kappa_score
from sklearn import metrics
#Predicting on test data
model_predicted = model.predict(price_X_test)


# Convert one-hot encoded labels to binary labels
y_test_binary = np.argmax(y_test_one_hot, axis=1)
model_predicted_binary = np.argmax(model_predicted, axis=1)


# Calculate Cohen's Kappa and other classification metrics
kappa = cohen_kappa_score(y_test_binary, model_predicted_binary)
accuracy = metrics.accuracy_score(y_test_binary, model_predicted_binary)
precision = metrics.precision_score(y_test_binary, model_predicted_binary, average='weighted')
recall = metrics.recall_score(y_test_binary, model_predicted_binary, average='weighted')
f1_score = metrics.f1_score(y_test_binary, model_predicted_binary, average='weighted')
print("ANN Kappa:", round(kappa, 3))
print("ANN Accuracy:", round(accuracy, 3))
print("ANN Precision:", round(precision, 3))
print("ANN Recall:", round(recall, 3))
print("ANN F1socre:", round(f1_score, 3))
# Out:
# 203/203 [==============================] - 0s 2ms/step
# ANN Kappa: 0.821
# ANN Accuracy: 0.911
# ANN Precision: 0.911
# ANN Recall: 0.911
# ANN F1socre: 0.911

# %%
from sklearn.metrics import classification_report
# Generate the classification report
clfreport = classification_report(y_test_binary, model_predicted_binary)

# Print the report
print("The result of the classification report is: \n ",clfreport)
# Out:
# The result of the classification report is:
#                 precision    recall  f1-score   support
#
#            0       0.92      0.90      0.91      3239
#            1       0.90      0.92      0.91      3245
#
#     accuracy                           0.91      6484
#    macro avg       0.91      0.91      0.91      6484
# weighted avg       0.91      0.91      0.91      6484

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(y_test_binary, model_predicted_binary)

# %% [markdown]
# The High Price houses are better classified than Low Price houses under Neural Network.

# %% [markdown]
# ####Gradient Boosting

# %% [markdown]
# Gradient Boosting is an ensemble learning technique that builds a strong predictive model by combining the predictions of multiple weaker models, typically decision trees, in an iterative manner, with a focus on correcting the errors made by the previous models.

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Create a Gradient Boosting classifier
gb_clf = GradientBoostingClassifier(random_state=2023)

# Fit the classifier on the training data
gb_clf.fit(price_X_train, price_y_train)

# Predict on the test data
gb_predicted = gb_clf.predict(price_X_test)

# Calculate and print the evaluation metrics for Gradient Boosting
print("Gradient Boosting Kappa:", round(metrics.cohen_kappa_score(price_y_test, gb_predicted), 3))
print("Gradient Boosting Accuracy:", round(metrics.accuracy_score(price_y_test, gb_predicted), 3))
print("Gradient Boosting Precision:", round(metrics.precision_score(price_y_test, gb_predicted, average='weighted'), 3))
print("Gradient Boosting Recall:", round(metrics.recall_score(price_y_test, gb_predicted, average='weighted'), 3))
print("Gradient Boosting F1 Score:", round(metrics.f1_score(price_y_test, gb_predicted, average='weighted'), 3))
# Out:
# Gradient Boosting Kappa: 0.818
# Gradient Boosting Accuracy: 0.909
# Gradient Boosting Precision: 0.909
# Gradient Boosting Recall: 0.909
# Gradient Boosting F1 Score: 0.909

# %%
# Generate and print the classification report
print("\nClassification Report:")
print(classification_report(price_y_test, gb_predicted))

# Generate and print the confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(price_y_test, gb_predicted))

ConfusionMatrixDisplay.from_predictions(price_y_test, gb_predicted)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91      3239
#            1       0.91      0.91      0.91      3245
#
#     accuracy                           0.91      6484
#    macro avg       0.91      0.91      0.91      6484
# weighted avg       0.91      0.91      0.91      6484
#
#
# Confusion Matrix:
# [[2930  309]
#  [ 281 2964]]

# %% [markdown]
# High Price houses have more correct classification than Low price Houses but Neural network has better classification for High price houses than gradient boosting whereas gradient boosting has higher correct classification for low price housing.

# %% [markdown]
# <a id = "cell_report"></a>
# ## 4. Experiments Report

# %% [markdown]
# *Provide a summary of experimental results, explain the meaning of your result
# and how your model can be used to address the related business problem.*

# %% [markdown]
# ###House Price Prediction

# %% [markdown]
# ![reg.png](data:image/png;base64,...)
#
# ![annreg.png](data:image/png;base64,...)

# %% [markdown]
# Based on these results, it is clear that the Artificial Neural Network (ANN) outperforms Linear Regression in predicting house prices for this specific dataset. It achieves lower MAE, MSE, and RMSE on both training and validation sets. The correlation values for the true and predicted values is also better for neural network with 0.89 compared to 0.831 for linear regression. There are many reasons for neural network performing better. Firstly, MLP  consist of multiple layers of interconnected nodes (neurons) with nonlinear activation functions. This allows them to capture and represent nonlinear patterns and relationships in data, which linear regression cannot handle effectively. This means, MLP is built on top of linear regression. Also, the model architure is complex than a simple linear regression and finally the overfitting is prevented through the use of regularization techniques.
#
# The ANN model can be used by the real estate company to make more accurate predictions of house prices, which is crucial for property valuation, investment decisions, and market analysis.
# Additionally, the ANN model can help the company identify factors and features that contribute significantly to house prices, providing valuable insights for pricing strategies and investment opportunities.

# %% [markdown]
# ####House Price Classification

# %% [markdown]
# ![ev.png](data:image/png;base64,...)

# %% [markdown]
# From the experiment summary, we can see the Artificial Neural Network (ANN) appears to be the best-performing model in terms of all metrics.
# With high Kappa and accuracy, it demonstrates strong overall predictive performance and agreement with actual labels. Gradient Boosting performs closely to the ANN and is an excellent alternative with high agreement, accuracy, and balanced precision and recall. SVM has a reasonably good performance but not as well to GB and ANN. Naive Bayes ont the other hand has a lowest performance. The highly accurate model will help real estate companies to segment the real estate market and different marketing strategies can be formed to buyers of each category.
